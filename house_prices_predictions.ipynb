# %%
import pandas as pd

# %%
house_price_train=pd.read_csv('train.csv')
house_price_test=pd.read_csv('test.csv')

# %%
print(house_price_train.shape)
print(house_price_test.shape)
# Out:
# (2016, 8)
# (505, 8)

# %%
print(house_price_train.info())
print(house_price_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   beds            2016 non-null   int64
#  1   baths           2016 non-null   float64
#  2   size            2016 non-null   float64
#  3   size_units      2016 non-null   object
#  4   lot_size        1669 non-null   float64
#  5   lot_size_units  1669 non-null   object
#  6   zip_code        2016 non-null   int64
#  7   price           2016 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 126.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   beds            505 non-null    int64
#  1   baths           505 non-null    float64
#  2   size            505 non-null    float64
# ...

# %%
print(house_price_train.describe())
print(house_price_test.describe())
# Out:
#               beds        baths          size     lot_size      zip_code  \
# count  2016.000000  2016.000000   2016.000000  1669.000000   2016.000000
# mean      2.857639     2.159970   1735.740575  3871.059694  98123.638889
# std       1.255092     1.002023    920.132591  2719.402066     22.650819
# min       1.000000     0.500000    250.000000     0.230000  98101.000000
# 25%       2.000000     1.500000   1068.750000  1252.000000  98108.000000
# 50%       3.000000     2.000000   1560.000000  4000.000000  98117.000000
# 75%       4.000000     2.500000   2222.500000  6000.000000  98126.000000
# max      15.000000     9.000000  11010.000000  9998.000000  98199.000000
#
#               price
# count  2.016000e+03
# mean   9.636252e+05
# std    9.440954e+05
# min    1.590000e+05
# 25%    6.017500e+05
# 50%    8.000000e+05
# 75%    1.105250e+06
# max    2.500000e+07
#              beds       baths         size     lot_size      zip_code  \
# ...

# %%
print(house_price_train.head)
print(house_price_test.head)
# Out:
# <bound method NDFrame.head of       beds  baths    size size_units  lot_size lot_size_units  zip_code  \
# 0        3    2.5  2590.0       sqft   6000.00           sqft     98144
# 1        4    2.0  2240.0       sqft      0.31           acre     98106
# 2        4    3.0  2040.0       sqft   3783.00           sqft     98107
# 3        4    3.0  3800.0       sqft   5175.00           sqft     98199
# 4        2    2.0  1042.0       sqft       NaN            NaN     98102
# ...    ...    ...     ...        ...       ...            ...       ...
# 2011     3    2.0  1370.0       sqft      0.50           acre     98112
# 2012     1    1.0   889.0       sqft       NaN            NaN     98121
# 2013     4    2.0  2140.0       sqft   6250.00           sqft     98199
# 2014     2    2.0   795.0       sqft       NaN            NaN     98103
# 2015     3    2.0  1710.0       sqft   4267.00           sqft     98133
#
#           price
# 0      795000.0
# 1      915000.0
# 2      950000.0
# ...

# %%
print(house_price_train.columns)
print(house_price_test.columns)
# Out:
# Index(['beds', 'baths', 'size', 'size_units', 'lot_size', 'lot_size_units',
#        'zip_code', 'price'],
#       dtype='object')
# Index(['beds', 'baths', 'size', 'size_units', 'lot_size', 'lot_size_units',
#        'zip_code', 'price'],
#       dtype='object')

# %%
house_price_train["lot_size_units"].unique()
# Out:
# array(['sqft', 'acre', nan], dtype=object)

# %%
house_price_train["beds"].unique()
# Out:
# array([ 3,  4,  2,  1,  5,  6,  9, 15, 14,  8,  7], dtype=int64)

# %%
house_price_train["baths"].unique()
# Out:
# array([2.5, 2. , 3. , 1. , 3.5, 1.5, 5.5, 5. , 4. , 8.5, 4.5, 6. , 0.5,
#        7. , 9. , 6.5])

# %%
house_price_train["size"].unique()
# Out:
# array([ 2590.,  2240.,  2040.,  3800.,  1042.,  1190.,   670.,  4510.,
#         1520.,  2340.,  1320.,  1800.,  2490.,  2650.,  2560.,   900.,
#         1360.,   550.,  2974.,  1989.,  1332.,  2668.,   770.,  1280.,
#         3200.,   889.,   508.,  3140.,  2000.,   792.,  1690.,  3000.,
#         1550.,   871.,  1940.,   474.,  1770.,  2510.,   750.,   573.,
#         1500.,  2920.,  2817.,   617.,  1523.,  1240.,  2280.,  3590.,
#         2478.,  2360.,   720.,  2480.,   780.,  2820.,  2900.,  1092.,
#         1731.,  1344.,  4040.,  2320.,  1070.,  1113.,  2100.,  2620.,
#         1270.,  2702.,  2031.,  2350.,  2640.,  1340.,  8660.,  1365.,
#          635.,   870.,  1510.,  1120.,  2580.,   875.,  2220.,   607.,
#         1496.,  2670.,  1810.,   582.,  1006.,  1530.,   820.,  1960.,
#         2110.,  3010.,  2200.,  1820.,  3040.,   800.,  1450.,   756.,
#          742.,  2400.,  1607.,  3057.,   649.,  3142.,  1050.,  1720.,
# ...

# %%
house_price_train["size"].min()
# Out:
# 250.0

# %%
house_price_train["size"].max()
# Out:
# 11010.0

# %%
house_price_train["size_units"].unique()
# Out:
# array(['sqft'], dtype=object)

# %%
house_price_train["lot_size"].unique()
# Out:
# array([6.000e+03, 3.100e-01, 3.783e+03, 5.175e+03,       nan, 1.000e+00,
#        7.410e+02, 9.500e+03, 1.386e+03, 3.993e+03, 5.757e+03, 6.380e+03,
#        5.200e+03, 3.840e+03, 1.607e+03, 1.101e+03, 5.589e+03, 5.250e+03,
#        9.100e+03, 9.260e+03, 2.300e-01, 5.000e+03, 8.077e+03, 1.733e+03,
#        5.520e+03, 1.400e+03, 2.900e-01, 8.778e+03, 3.349e+03, 2.700e-01,
#        1.056e+03, 6.323e+03, 6.375e+03, 4.900e-01, 3.000e+03, 5.038e+03,
#        3.932e+03, 3.600e-01, 2.761e+03, 6.600e+03, 7.500e+03, 5.829e+03,
#        6.720e+03, 3.060e+03, 6.250e+03, 3.600e+03, 5.500e+03, 7.514e+03,
#        8.240e+03, 1.110e+03, 8.965e+03, 4.864e+03, 4.080e+03, 1.333e+03,
#        7.320e+03, 7.440e+03, 5.120e+03, 2.800e-01, 6.554e+03, 1.239e+03,
#        6.096e+03, 2.600e-01, 9.740e+02, 3.405e+03, 6.827e+03, 5.000e-01,
#        1.336e+03, 5.100e+03, 2.400e-01, 4.000e+03, 4.050e+00, 6.180e+03,
#        5.250e+02, 5.400e+03, 7.650e+03, 3.750e+03, 8.500e+03, 2.500e-01,
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(house_price_train['price'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(house_price_train['size'], house_price_train['price'], color='orange', alpha=0.5)
plt.title('House Size vs. Price')
plt.xlabel('Size')
plt.ylabel('Price')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='zip_code', y='price', data=house_price_train)
plt.title('House Prices by Zip Code')
plt.xlabel('Zip Code')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
avg_price_by_bedrooms = house_price_train.groupby('beds')['price'].mean().reset_index()
plt.bar(avg_price_by_bedrooms['beds'], avg_price_by_bedrooms['price'], color='green')
plt.title('Average Price by Number of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Average Price')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Load the datasets
house_price_train = pd.read_csv('train.csv')
house_price_test = pd.read_csv('test.csv')

X_train = house_price_train[['beds', 'baths', 'size', 'lot_size', 'zip_code']]
y_train = house_price_train['price']

X_test = house_price_test[['beds', 'baths', 'size', 'lot_size', 'zip_code']]

# Impute missing values
imputer = SimpleImputer(strategy='median')  
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(),
    'Gradient Boosting': GradientBoostingRegressor(),
    'Support Vector Machine': SVR(),
    'Neural Network': MLPRegressor(max_iter=1000) 
}


for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    house_price_test[name + '_predicted_price'] = y_pred
    print(f"{name}: Predictions ", y_pred)
# Out:
# Linear Regression: Predictions generated. [1602374.822808   1765749.05986439  641883.69667624 1058384.80327546
#  1186991.49047716  646824.84283314  630436.64221301 1685247.82248469
#   940268.19739124  534500.03735903  987244.57307036  701981.46127899
#  1304811.75115631  837754.19423206  537944.21502965 1334561.2082749
#  1257638.53310682  872793.18601532  975336.10046576 1320310.98661984
#   660766.69915201 1338785.30447208 1019933.830002    544373.88898604
#   691522.16413564  801534.18889359  748835.36729212  761971.56148362
#   975712.78145197  497778.52447091  621509.53170419  517115.72232375
#  1810726.84160742  443374.80569496 1146341.80917701 1068804.7330912
#   513948.83004317 1213784.45388266 1211637.52344726 1535258.0073111
#  1660507.94832885  772690.01934443 1858251.0310051  1169788.98719893
#  1889484.48138763 1754541.39340716 1160505.53815135 1018312.62654053
#  1317407.18263064  627434.78031801  802585.94851711  475748.92484559
# ...
